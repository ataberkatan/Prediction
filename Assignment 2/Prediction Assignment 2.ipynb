# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#I want to ignore the warning messages.
import warnings
warnings.filterwarnings('ignore')

# %%
df_all = pd.read_csv('listings.csv.gz') #Pandas can directly read CSVs from gz formatted zips.

# %%
df_all.head()
# Out:
#       id                         listing_url       scrape_id last_scraped  \
# 0  27271  https://www.airbnb.com/rooms/27271  20221230163509   2022-12-31
# 1  28277  https://www.airbnb.com/rooms/28277  20221230163509   2022-12-31
# 2  28318  https://www.airbnb.com/rooms/28318  20221230163509   2022-12-31
# 3  29241  https://www.airbnb.com/rooms/29241  20221230163509   2022-12-31
# 4  30697  https://www.airbnb.com/rooms/30697  20221230163509   2022-12-31
#
#             source                                  name  \
# 0      city scrape  Lovely apartment in perfect location
# 1      city scrape      Duplex Apartment 11 with Terrace
# 2      city scrape       Cosy home overlooking Bosphorus
# 3      city scrape         ↪ Istanbul, Your second house
# 4  previous scrape             nice home in popular area
#
#                                          description  \
# 0  This is a  nicely decorated apartment in an an...
# 1  <b>The space</b><br />The first advantage to s...
# ...

# %%
df_all.describe()
# Out:
#                  id     scrape_id       host_id  host_listings_count  \
# count  3.671700e+04  3.671700e+04  3.671700e+04         36717.000000
# mean   3.936399e+17  2.022123e+13  2.758778e+08            14.092709
# std    3.488273e+17  0.000000e+00  1.721033e+08            53.528775
# min    2.727100e+04  2.022123e+13  1.969200e+04             1.000000
# 25%    4.555318e+07  2.022123e+13  9.980339e+07             1.000000
# 50%    5.996185e+17  2.022123e+13  3.046935e+08             3.000000
# 75%    7.208346e+17  2.022123e+13  4.418858e+08             8.000000
# max    7.932737e+17  2.022123e+13  4.933383e+08          1596.000000
#
#        host_total_listings_count  neighbourhood_group_cleansed      latitude  \
# count               36717.000000                           0.0  36717.000000
# mean                   25.375221                           NaN     41.028908
# std                   142.651086                           NaN      0.050255
# ...

# %%
df_all.corr()
# Out:
#                                                     id  scrape_id   host_id  \
# id                                            1.000000        NaN  0.444048
# scrape_id                                          NaN        NaN       NaN
# host_id                                       0.444048        NaN  1.000000
# host_listings_count                           0.052315        NaN -0.008475
# host_total_listings_count                     0.071815        NaN -0.008281
# neighbourhood_group_cleansed                       NaN        NaN       NaN
# latitude                                      0.013716        NaN  0.017499
# longitude                                    -0.036130        NaN -0.055508
# accommodates                                  0.029387        NaN -0.017561
# bathrooms                                          NaN        NaN       NaN
# bedrooms                                      0.005499        NaN -0.002697
# ...

# %%
#deneme 1-2-3
